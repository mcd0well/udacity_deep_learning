# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
    save = pickle.load(f)
    train_dataset = save['train_dataset']
    train_labels = save['train_labels']
    valid_dataset = save['valid_dataset']
    valid_labels = save['valid_labels']
    test_dataset = save['test_dataset']
    test_labels = save['test_labels']
    del save  # hint to help gc free up memory
    print('Training set', train_dataset.shape, train_labels.shape)
    print('Validation set', valid_dataset.shape, valid_labels.shape)
    print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (400000, 28, 28) (400000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
    
    dataset = dataset.reshape(
        (-1, image_size, image_size, num_channels)
    ).astype(np.float32)
    
    labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
    return dataset, labels

train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)

print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (400000, 28, 28, 1) (400000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 64
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    
    layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    
    layer3_weights = tf.Variable(tf.truncated_normal([image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
    layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
    # Model.
    def model(data):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
        
        hidden = tf.nn.relu(conv + layer1_biases)
        
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
        
        hidden = tf.nn.relu(conv + layer2_biases)
        
        shape = hidden.get_shape().as_list()
        
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        
        return tf.matmul(hidden, layer4_weights) + layer4_biases
  
    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))

    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(
            valid_prediction.eval(), valid_labels))

    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 4.698073
# Minibatch accuracy: 17.2%
# Validation accuracy: 9.6%
# Minibatch loss at step 50: 2.365236
# Minibatch accuracy: 17.2%
# Validation accuracy: 13.9%
# Minibatch loss at step 100: 2.269464
# Minibatch accuracy: 9.4%
# Validation accuracy: 22.2%
# Minibatch loss at step 150: 1.893042
# Minibatch accuracy: 29.7%
# Validation accuracy: 32.1%
# Minibatch loss at step 200: 1.778751
# Minibatch accuracy: 39.1%
# Validation accuracy: 35.7%
# Minibatch loss at step 250: 1.739872
# Minibatch accuracy: 35.9%
# Validation accuracy: 42.5%
# Minibatch loss at step 300: 1.364942
# Minibatch accuracy: 48.4%
# Validation accuracy: 48.3%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-a720f7f01800> in <module>()
#      10         batch_labels = train_labels[offset:(offset + batch_size), :]
#      11         feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
# ---> 12         _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
#      13
#      14         if (step % 50 == 0):
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict)
#     313         `Tensor` that doesn't exist.
#     314     """
# --> 315     return self._run(None, fetches, feed_dict)
#     316
#     317   def partial_run(self, handle, fetches, feed_dict=None):
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict)
#     509     # Run request and get response.
#     510     results = self._do_run(handle, target_list, unique_fetches,
# --> 511                            feed_dict_string)
#     512
#     513     # User may have fetched the same tensor multiple times, but we
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict)
#     562     if handle is None:
#     563       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 564                            target_list)
#     565     else:
#     566       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#     569   def _do_call(self, fn, *args):
#     570     try:
# --> 571       return fn(*args)
#     572     except tf_session.StatusNotOK as e:
#     573       e_type, e_value, e_traceback = sys.exc_info()
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list)
#     553       # Ensure any changes to the graph are reflected in the runtime.
#     554       self._extend_graph()
# --> 555       return tf_session.TF_Run(session, feed_dict, fetch_list, target_list)
#     556
#     557     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 124
patch_size = 5
depth = 16
num_hidden = 64
beta = 0.0001
dropout = True
keep_prob = 0.8

graph = tf.Graph()

with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    
    layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    
    layer3_weights = tf.Variable(tf.truncated_normal([image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
    layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
    # Model.
    def model(data):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        pool = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        
        hidden = tf.nn.relu(pool + layer1_biases)
        if dropout:
            hidden = tf.nn.dropout(hidden, keep_prob)
        
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
        pool = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        
        hidden = tf.nn.relu(pool + layer2_biases)
        if dropout:
            hidden = tf.nn.dropout(hidden, keep_prob)
        
        shape = hidden.get_shape().as_list()
        
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        if dropout:
            hidden = tf.nn.dropout(hidden, keep_prob)
        
        return tf.matmul(hidden, layer4_weights) + layer4_biases
  
    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
    # adding regularizers
    regularizers = (tf.nn.l2_loss(layer1_weights) +
                  tf.nn.l2_loss(layer2_weights) +
                  tf.nn.l2_loss(layer3_weights) +
                  tf.nn.l2_loss(layer4_weights)
                 )
    # Add the regularization term to the loss.
    loss += beta * regularizers
    
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 10001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(
            valid_prediction.eval(), valid_labels))

    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 4.584300
# Minibatch accuracy: 3.1%
# Validation accuracy: 9.8%
# Minibatch loss at step 50: 2.106802
# Minibatch accuracy: 25.0%
# Validation accuracy: 22.3%
# Minibatch loss at step 100: 1.742596
# Minibatch accuracy: 46.9%
# Validation accuracy: 50.8%
# Minibatch loss at step 150: 1.198810
# Minibatch accuracy: 60.9%
# Validation accuracy: 62.9%
# Minibatch loss at step 200: 1.091784
# Minibatch accuracy: 64.1%
# Validation accuracy: 68.3%
# Minibatch loss at step 250: 1.199207
# Minibatch accuracy: 70.3%
# Validation accuracy: 71.8%
# Minibatch loss at step 300: 1.106125
# Minibatch accuracy: 64.1%
# Validation accuracy: 72.7%
# Minibatch loss at step 350: 0.926973
# Minibatch accuracy: 79.7%
# Validation accuracy: 74.3%
# Minibatch loss at step 400: 0.917939
# Minibatch accuracy: 70.3%
# Validation accuracy: 74.8%
# Minibatch loss at step 450: 0.752232
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.8%
# Minibatch loss at step 500: 0.849964
# Minibatch accuracy: 76.6%
# Validation accuracy: 76.7%
# Minibatch loss at step 550: 0.757263
# Minibatch accuracy: 79.7%
# Validation accuracy: 77.7%
# Minibatch loss at step 600: 0.836146
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.0%
# Minibatch loss at step 650: 0.790403
# Minibatch accuracy: 76.6%
# Validation accuracy: 78.7%
# Minibatch loss at step 700: 0.761922
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.6%
# Minibatch loss at step 750: 0.523090
# Minibatch accuracy: 85.9%
# Validation accuracy: 79.9%
# Minibatch loss at step 800: 0.589903
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.9%
# Minibatch loss at step 850: 0.707757
# Minibatch accuracy: 78.1%
# Validation accuracy: 80.2%
# Minibatch loss at step 900: 0.978386
# Minibatch accuracy: 73.4%
# Validation accuracy: 80.1%
# Minibatch loss at step 950: 0.871547
# Minibatch accuracy: 73.4%
# Validation accuracy: 80.8%
# Minibatch loss at step 1000: 0.583533
# Minibatch accuracy: 84.4%
# Validation accuracy: 80.5%
# Minibatch loss at step 1050: 0.742298
# Minibatch accuracy: 82.8%
# Validation accuracy: 81.5%
# Minibatch loss at step 1100: 0.646549
# Minibatch accuracy: 78.1%
# Validation accuracy: 81.0%
# Minibatch loss at step 1150: 0.695023
# Minibatch accuracy: 76.6%
# Validation accuracy: 80.7%
# Minibatch loss at step 1200: 0.646968
# Minibatch accuracy: 84.4%
# Validation accuracy: 81.5%
# Minibatch loss at step 1250: 0.835487
# Minibatch accuracy: 73.4%
# Validation accuracy: 81.4%
# Minibatch loss at step 1300: 0.406210
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.9%
# Minibatch loss at step 1350: 0.417728
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.8%
# Minibatch loss at step 1400: 0.756415
# Minibatch accuracy: 78.1%
# Validation accuracy: 82.7%
# Minibatch loss at step 1450: 0.600441
# Minibatch accuracy: 84.4%
# Validation accuracy: 82.3%
# Minibatch loss at step 1500: 0.543689
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.3%
# Minibatch loss at step 1550: 0.554861
# Minibatch accuracy: 79.7%
# Validation accuracy: 82.2%
# Minibatch loss at step 1600: 0.525997
# Minibatch accuracy: 84.4%
# Validation accuracy: 82.6%
# Minibatch loss at step 1650: 0.810247
# Minibatch accuracy: 79.7%
# Validation accuracy: 82.8%
# Minibatch loss at step 1700: 0.648209
# Minibatch accuracy: 82.8%
# Validation accuracy: 82.6%
# Minibatch loss at step 1750: 0.811400
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 1800: 0.626573
# Minibatch accuracy: 79.7%
# Validation accuracy: 83.4%
# Minibatch loss at step 1850: 0.958426
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.1%
# Minibatch loss at step 1900: 0.547946
# Minibatch accuracy: 89.1%
# Validation accuracy: 83.5%
# Minibatch loss at step 1950: 0.690314
# Minibatch accuracy: 78.1%
# Validation accuracy: 83.4%
# Minibatch loss at step 2000: 0.519970
# Minibatch accuracy: 84.4%
# Validation accuracy: 83.5%
# Minibatch loss at step 2050: 0.547725
# Minibatch accuracy: 78.1%
# Validation accuracy: 83.7%
# Minibatch loss at step 2100: 0.541499
# Minibatch accuracy: 82.8%
# Validation accuracy: 83.7%
# Minibatch loss at step 2150: 0.509735
# Minibatch accuracy: 85.9%
# Validation accuracy: 83.4%
# Minibatch loss at step 2200: 0.576392
# Minibatch accuracy: 85.9%
# Validation accuracy: 84.0%
# Minibatch loss at step 2250: 0.487250
# Minibatch accuracy: 85.9%
# Validation accuracy: 84.1%
# Minibatch loss at step 2300: 0.552948
# Minibatch accuracy: 82.8%
# Validation accuracy: 83.9%
# Minibatch loss at step 2350: 0.751584
# Minibatch accuracy: 79.7%
# Validation accuracy: 83.6%
# Minibatch loss at step 2400: 0.579289
# Minibatch accuracy: 79.7%
# Validation accuracy: 84.1%
# Minibatch loss at step 2450: 0.558810
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.3%
# Minibatch loss at step 2500: 0.503685
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.5%
# Minibatch loss at step 2550: 0.529507
# Minibatch accuracy: 85.9%
# Validation accuracy: 84.3%
# Minibatch loss at step 2600: 0.608461
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.3%
# Minibatch loss at step 2650: 0.574660
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.5%
# Minibatch loss at step 2700: 0.579490
# Minibatch accuracy: 82.8%
# Validation accuracy: 84.5%
# Minibatch loss at step 2750: 0.577095
# Minibatch accuracy: 85.9%
# Validation accuracy: 84.6%
# Minibatch loss at step 2800: 0.453674
# Minibatch accuracy: 85.9%
# Validation accuracy: 84.3%
# Minibatch loss at step 2850: 0.713060
# Minibatch accuracy: 79.7%
# Validation accuracy: 84.9%
# Minibatch loss at step 2900: 0.522572
# Minibatch accuracy: 85.9%
# Validation accuracy: 84.5%
# Minibatch loss at step 2950: 0.570177
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.9%
# Minibatch loss at step 3000: 0.644775
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.4%
# Minibatch loss at step 3050: 0.663554
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.9%
# Minibatch loss at step 3100: 0.788258
# Minibatch accuracy: 79.7%
# Validation accuracy: 84.9%
# Minibatch loss at step 3150: 0.279947
# Minibatch accuracy: 92.2%
# Validation accuracy: 84.9%
# Minibatch loss at step 3200: 0.350507
# Minibatch accuracy: 92.2%
# Validation accuracy: 85.1%
# Minibatch loss at step 3250: 0.681623
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.7%
# Minibatch loss at step 3300: 0.689470
# Minibatch accuracy: 82.8%
# Validation accuracy: 85.3%
# Minibatch loss at step 3350: 0.573340
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.1%
# Minibatch loss at step 3400: 0.624622
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 3450: 0.332193
# Minibatch accuracy: 89.1%
# Validation accuracy: 85.5%
# Minibatch loss at step 3500: 0.551477
# Minibatch accuracy: 85.9%
# Validation accuracy: 85.1%
# Minibatch loss at step 3550: 0.552827
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.6%
# Minibatch loss at step 3600: 0.723916
# Minibatch accuracy: 76.6%
# Validation accuracy: 85.5%
# Minibatch loss at step 3650: 0.759154
# Minibatch accuracy: 76.6%
# Validation accuracy: 85.3%
# Minibatch loss at step 3700: 0.419900
# Minibatch accuracy: 89.1%
# Validation accuracy: 85.2%
# Minibatch loss at step 3750: 0.425692
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.5%
# Minibatch loss at step 3800: 0.670895
# Minibatch accuracy: 82.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 3850: 0.533028
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.1%
# Minibatch loss at step 3900: 0.767615
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.6%
# Minibatch loss at step 3950: 0.506750
# Minibatch accuracy: 82.8%
# Validation accuracy: 85.5%
# Minibatch loss at step 4000: 0.383769
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.3%
# Minibatch loss at step 4050: 0.302991
# Minibatch accuracy: 92.2%
# Validation accuracy: 85.8%
# Minibatch loss at step 4100: 0.640977
# Minibatch accuracy: 82.8%
# Validation accuracy: 86.0%
# Minibatch loss at step 4150: 0.397643
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.7%
# Minibatch loss at step 4200: 0.277260
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 4250: 0.593407
# Minibatch accuracy: 82.8%
# Validation accuracy: 85.6%
# Minibatch loss at step 4300: 0.496779
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.8%
# Minibatch loss at step 4350: 0.484846
# Minibatch accuracy: 85.9%
# Validation accuracy: 85.7%
# Minibatch loss at step 4400: 0.416720
# Minibatch accuracy: 89.1%
# Validation accuracy: 85.7%
# Minibatch loss at step 4450: 0.471507
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.7%
# Minibatch loss at step 4500: 0.503859
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.8%
# Minibatch loss at step 4550: 0.396339
# Minibatch accuracy: 92.2%
# Validation accuracy: 85.8%
# Minibatch loss at step 4600: 0.452185
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.8%
# Minibatch loss at step 4650: 0.594637
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.6%
# Minibatch loss at step 4700: 0.425074
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
# Minibatch loss at step 4750: 0.582796
# Minibatch accuracy: 82.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 4800: 0.385908
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
# Minibatch loss at step 4850: 0.457148
# Minibatch accuracy: 89.1%
# Validation accuracy: 85.9%
# Minibatch loss at step 4900: 0.462082
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.4%
# Minibatch loss at step 4950: 0.488111
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 5000: 0.478360
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 5050: 0.352305
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 5100: 0.490311
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 5150: 0.314824
# Minibatch accuracy: 92.2%
# Validation accuracy: 86.1%
# Minibatch loss at step 5200: 0.520405
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 5250: 0.599269
# Minibatch accuracy: 79.7%
# Validation accuracy: 86.3%
# Minibatch loss at step 5300: 0.378226
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.4%
# Minibatch loss at step 5350: 0.391601
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# Minibatch loss at step 5400: 0.498051
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.4%
# Minibatch loss at step 5450: 0.401279
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.3%
# Minibatch loss at step 5500: 0.367055
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.5%
# Minibatch loss at step 5550: 0.491244
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.3%
# Minibatch loss at step 5600: 0.537916
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.6%
# Minibatch loss at step 5650: 0.415578
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 5700: 0.509496
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.0%
# Minibatch loss at step 5750: 0.672563
# Minibatch accuracy: 82.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 5800: 0.462025
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 5850: 0.774736
# Minibatch accuracy: 76.6%
# Validation accuracy: 86.7%
# Minibatch loss at step 5900: 0.293587
# Minibatch accuracy: 92.2%
# Validation accuracy: 86.3%
# Minibatch loss at step 5950: 0.526403
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.7%
# Minibatch loss at step 6000: 0.368171
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.4%
# Minibatch loss at step 6050: 0.281127
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.6%
# Minibatch loss at step 6100: 0.358278
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.5%
# Minibatch loss at step 6150: 0.289563
# Minibatch accuracy: 92.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 6200: 0.449368
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.7%
# Minibatch loss at step 6250: 0.529747
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.0%
# Minibatch loss at step 6300: 0.413011
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.5%
# Minibatch loss at step 6350: 0.423136
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.7%
# Minibatch loss at step 6400: 0.336733
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.1%
# Minibatch loss at step 6450: 0.416871
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.8%
# Minibatch loss at step 6500: 0.577639
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.9%
# Minibatch loss at step 6550: 0.433409
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.5%
# Minibatch loss at step 6600: 0.429133
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss at step 6650: 0.586741
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.7%
# Minibatch loss at step 6700: 0.394325
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.7%
# Minibatch loss at step 6750: 0.535236
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 6800: 0.288235
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.7%
# Minibatch loss at step 6850: 0.200740
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 6900: 0.333046
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.0%
# Minibatch loss at step 6950: 0.377869
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.8%
# Minibatch loss at step 7000: 0.508936
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.9%
# Minibatch loss at step 7050: 0.387164
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.2%
# Minibatch loss at step 7100: 0.496604
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.0%
# Minibatch loss at step 7150: 0.490891
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 7200: 0.417378
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.0%
# Minibatch loss at step 7250: 0.327643
# Minibatch accuracy: 92.2%
# Validation accuracy: 86.9%
# Minibatch loss at step 7300: 0.485746
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.1%
# Minibatch loss at step 7350: 0.329862
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.7%
# Minibatch loss at step 7400: 0.487614
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.7%
# Minibatch loss at step 7450: 0.325845
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.0%
# Minibatch loss at step 7500: 0.364804
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.2%
# Minibatch loss at step 7550: 0.173866
# Minibatch accuracy: 95.3%
# Validation accuracy: 87.1%
# Minibatch loss at step 7600: 0.353318
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.9%
# Minibatch loss at step 7650: 0.483021
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.1%
# Minibatch loss at step 7700: 0.255780
# Minibatch accuracy: 95.3%
# Validation accuracy: 87.2%
# Minibatch loss at step 7750: 0.322893
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.0%
# Minibatch loss at step 7800: 0.485165
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.1%
# Minibatch loss at step 7850: 0.434104
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 7900: 0.402092
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.4%
# Minibatch loss at step 7950: 0.340019
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 8000: 0.517596
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.0%
# Minibatch loss at step 8050: 0.428509
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.1%
# Minibatch loss at step 8100: 0.563194
# Minibatch accuracy: 79.7%
# Validation accuracy: 87.2%
# Minibatch loss at step 8150: 0.284508
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.6%
# Minibatch loss at step 8200: 0.550375
# Minibatch accuracy: 82.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 8250: 0.673020
# Minibatch accuracy: 79.7%
# Validation accuracy: 87.1%
# Minibatch loss at step 8300: 0.470993
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.1%
# Minibatch loss at step 8350: 1.037507
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.2%
# Minibatch loss at step 8400: 0.683025
# Minibatch accuracy: 79.7%
# Validation accuracy: 87.4%
# Minibatch loss at step 8450: 0.335985
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 8500: 0.656101
# Minibatch accuracy: 82.8%
# Validation accuracy: 87.4%
# Minibatch loss at step 8550: 0.462453
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.4%
# Minibatch loss at step 8600: 0.659167
# Minibatch accuracy: 78.1%
# Validation accuracy: 87.2%
# Minibatch loss at step 8650: 0.258610
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.3%
# Minibatch loss at step 8700: 0.357427
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.4%
# Minibatch loss at step 8750: 0.351341
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.2%
# Minibatch loss at step 8800: 0.551083
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.4%
# Minibatch loss at step 8850: 0.386658
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 8900: 0.518066
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.6%
# Minibatch loss at step 8950: 0.406156
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.2%
# Minibatch loss at step 9000: 0.384702
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 9050: 0.340189
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.5%
# Minibatch loss at step 9100: 0.551701
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.0%
# Minibatch loss at step 9150: 0.606340
# Minibatch accuracy: 82.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 9200: 0.585261
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.6%
# Minibatch loss at step 9250: 0.525732
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.6%
# Minibatch loss at step 9300: 0.425892
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.5%
# Minibatch loss at step 9350: 0.658875
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.5%
# Minibatch loss at step 9400: 0.696265
# Minibatch accuracy: 78.1%
# Validation accuracy: 87.3%
# Minibatch loss at step 9450: 0.467649
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 9500: 0.524721
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.1%
# Minibatch loss at step 9550: 0.448352
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.4%
# Minibatch loss at step 9600: 0.463005
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 9650: 0.602866
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.6%
# Minibatch loss at step 9700: 0.543804
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.7%
# Minibatch loss at step 9750: 0.300312
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.6%
# Minibatch loss at step 9800: 0.664986
# Minibatch accuracy: 79.7%
# Validation accuracy: 87.5%
# Minibatch loss at step 9850: 0.264470
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.0%
# Minibatch loss at step 9900: 0.225631
# Minibatch accuracy: 95.3%
# Validation accuracy: 87.7%
# Minibatch loss at step 9950: 0.428144
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.7%
# Minibatch loss at step 10000: 0.440240
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.8%
# Test accuracy: 93.1%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---
